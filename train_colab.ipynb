# %% [markdown]
# # Gated Attention ViT — CIFAR-10 Training

# %%
# !git clone -b experiment/vision https://github.com/aarohiz/gated-attention-transformer.git
# %cd gated-attention-transformer
# Out:
# Cloning into 'gated-attention-transformer'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 2), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 6.47 KiB | 6.47 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/gated-attention-transformer
# Cloning into 'gated-attention-transformer'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 2), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 6.47 KiB | 6.47 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/gated-attention-transformer/gated-attention-transformer

# %%
# !pip install pyyaml -q

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !python -m experiments.vision.train
# Out:
# Device: cuda
#
# ...
#   STANDARD | SMALL
# ...
#   Parameters: 4,771,082
# 100% 170M/170M [00:13<00:00, 12.5MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /content/gated-attention-transformer/experiments/vision/train.py:164: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp else None
# ...

# %%
import os
for f in os.listdir("experiments/vision/results"):
    print(f)
# Out:
# standard_small_20260418_053245_attn_epoch1.json
# standard_medium_20260418_060146_attn_final.json
# gated_small_20260418_063212_attn_mid.json
# gated_medium_20260418_070142_attn_mid.json
# summary_20260418_073354.json
# standard_medium_20260418_060146_attn_epoch1.json
# standard_small_20260418_053245_attn_mid.json
# gated_medium_20260418_070142_attn_epoch1.json
# gated_small_20260418_063212_attn_epoch1.json
# gated_medium_20260418_070142_attn_final.json
# standard_small_20260418_053245_attn_final.json
# gated_small_20260418_063212_attn_final.json
# gated_small_20260418_063212.json
# gated_medium_20260418_070142.json
# standard_medium_20260418_060146.json
# standard_small_20260418_053245.json
# standard_medium_20260418_060146_attn_mid.json

# %%
from google.colab import files
import os

results_dir = "/content/gated-attention-transformer/experiments/vision/results"
for f in os.listdir(results_dir):
    if f.endswith(".json") and "attn" not in f:
        files.download(os.path.join(results_dir, f))

# %%
# !cp -r /content/gated-attention-transformer/experiments/vision/results/ experiments/vision/results/
# !git config user.email "vriddhimittal14@gmail.com"
# !git config user.name "Vriddhi"
# !git add experiments/vision/results/
# !git commit -m "results: add all 4 vision training runs"
# !git push origin experiment/vision

# %%
import os
for root, dirs, files in os.walk("/content"):
    for f in files:
        if f.endswith(".json") and "attn" not in f and "standard" in f or f.endswith(".json") and "gated" in f and "attn" not in f:
            print(os.path.join(root, f))
# Out:
# /content/gated-attention-transformer/experiments/vision/results/gated_small_20260418_063212.json
# /content/gated-attention-transformer/experiments/vision/results/gated_medium_20260418_070142.json
# /content/gated-attention-transformer/experiments/vision/results/standard_medium_20260418_060146.json
# /content/gated-attention-transformer/experiments/vision/results/standard_small_20260418_053245.json

# %%
from google.colab import files

result_files = [
    "/content/gated-attention-transformer/experiments/vision/results/gated_small_20260418_063212.json",
    "/content/gated-attention-transformer/experiments/vision/results/gated_medium_20260418_070142.json",
    "/content/gated-attention-transformer/experiments/vision/results/standard_medium_20260418_060146.json",
    "/content/gated-attention-transformer/experiments/vision/results/standard_small_20260418_053245.json"
]

for f in result_files:
    files.download(f)

# %%
import json
with open("/content/gated-attention-transformer/experiments/vision/results/standard_small_20260418_053245.json") as f:
    print(json.dumps(json.load(f)))
# Out:
# [{"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small", "epoch": 1, "train_loss": 2.0024, "val_loss": 1.918588, "val_accuracy": 0.3367}, {"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small", "epoch": 2, "train_loss": 1.860313, "val_loss": 1.760599, "val_accuracy": 0.4132}, {"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small", "epoch": 3, "train_loss": 1.704332, "val_loss": 1.597245, "val_accuracy": 0.498}, {"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small", "epoch": 4, "train_loss": 1.585262, "val_loss": 1.510252, "val_accuracy": 0.5371}, {"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small", "epoch": 5, "train_loss": 1.513368, "val_loss": 1.454593, "val_accuracy": 0.5535}, {"experiment": "standard_small_20260418_053245", "model_type": "standard", "model_size": "small
# ...

# %%
import json
with open("/content/gated-attention-transformer/experiments/vision/results/standard_medium_20260418_060146.json") as f:
    print(json.dumps(json.load(f)))
# Out:
# [{"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_size": "medium", "epoch": 1, "train_loss": 1.962195, "val_loss": 1.905919, "val_accuracy": 0.3316}, {"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_size": "medium", "epoch": 2, "train_loss": 1.785676, "val_loss": 1.655845, "val_accuracy": 0.4615}, {"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_size": "medium", "epoch": 3, "train_loss": 1.617763, "val_loss": 1.633857, "val_accuracy": 0.4869}, {"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_size": "medium", "epoch": 4, "train_loss": 1.52536, "val_loss": 1.469779, "val_accuracy": 0.552}, {"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_size": "medium", "epoch": 5, "train_loss": 1.459418, "val_loss": 1.417498, "val_accuracy": 0.5855}, {"experiment": "standard_medium_20260418_060146", "model_type": "standard", "model_s
# ...

# %%
import json
with open("/content/gated-attention-transformer/experiments/vision/results/gated_small_20260418_063212.json") as f:
    print(json.dumps(json.load(f)))
# Out:
# [{"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 1, "train_loss": 2.017571, "val_loss": 1.9716, "val_accuracy": 0.3103}, {"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 2, "train_loss": 1.876596, "val_loss": 1.805792, "val_accuracy": 0.3997}, {"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 3, "train_loss": 1.710901, "val_loss": 1.595157, "val_accuracy": 0.4888}, {"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 4, "train_loss": 1.587586, "val_loss": 1.467055, "val_accuracy": 0.5522}, {"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 5, "train_loss": 1.510434, "val_loss": 1.467225, "val_accuracy": 0.5557}, {"experiment": "gated_small_20260418_063212", "model_type": "gated", "model_size": "small", "epoch": 6, "train_loss": 1.4551
# ...

# %%
import json
with open("/content/gated-attention-transformer/experiments/vision/results/gated_medium_20260418_070142.json") as f:
    print(json.dumps(json.load(f)))
# Out:
# [{"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 1, "train_loss": 1.975403, "val_loss": 1.921919, "val_accuracy": 0.3439}, {"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 2, "train_loss": 1.792847, "val_loss": 1.652128, "val_accuracy": 0.4712}, {"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 3, "train_loss": 1.629276, "val_loss": 1.545908, "val_accuracy": 0.5153}, {"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 4, "train_loss": 1.526105, "val_loss": 1.453058, "val_accuracy": 0.5557}, {"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 5, "train_loss": 1.458331, "val_loss": 1.372006, "val_accuracy": 0.5966}, {"experiment": "gated_medium_20260418_070142", "model_type": "gated", "model_size": "medium", "epoch": 6, "train
# ...

# %%
import os
for f in os.listdir("experiments/vision/results"):
    print(f)

# %%
# !pip install matplotlib -q
import subprocess
result = subprocess.run(
    ['python', 'dashboard/plot_results.py'],
    cwd='/content/gated-attention-transformer',
    capture_output=True, text=True
)
print(result.stdout)
print(result.stderr)

# %%
import json, os

path = "/content/gated-attention-transformer/experiments/vision/results/"
for f in ["standard_small_20260418_053245.json", "standard_medium_20260418_060146.json", 
          "gated_small_20260418_063212.json", "gated_medium_20260418_070142.json"]:
    with open(path + f) as file:
        print(f"=={f}==")
        print(file.read())

# %%
import os
print(os.listdir("/content/gated-attention-transformer/experiments/vision/results"))
